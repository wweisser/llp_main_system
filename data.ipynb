# %%
import sqlite3
import data_vault_main as dbm

conn = sqlite3.connect(r'C:\Users\whwei\OneDrive\coding\CDI_500_readout\data_vault.db')
c = conn.cursor()
dbm.create_table(c, conn, 'time_series_data')
# Out:
# 0

# %%
dbm.show_database(c)
conn.close
# Out:
# [('sqlite_sequence',), ('time_series_data',)]
# <function Connection.close()>

# %%
c.execute("SELECT * FROM time_series")
print(c.fetchone())
# Out:
# (1, 1, 154113, 7.44, 40, 100, 37.1, 20, -4.5, 98, 5.4, 0, 0, 0, 7.2, 50, 50, 36.9, 85, 23, 7.8)

# %%
print(c.fetchall())
# Out:
# []

# %%
c.execute("DROP TABLE time_series");

# %%
c.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(c.fetchall())
# Out:
# [('sqlite_sequence',), ('time_series_data',)]
