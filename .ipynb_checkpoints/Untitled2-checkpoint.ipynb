# %%
import sqlite3
import database

conn = sqlite3.connect('data.db')
c = conn.cursor()
c.execute("""CREATE TABLE IF NOT EXISTS cdi(
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        Time NUMERIC NOT NULL,
        artpH NUMERIC,
        artpCO2 NUMERIC,
        artpO2 NUMERIC,
        artTEMP NUMERIC,
        HCO3 NUMERIC,
        BE NUMERIC,
        cSO2 NUMERIC,
        K NUMERIC,
        VO2 NUMERIC,
        Q NUMERIC,
        BSA NUMERIC,
        venpH NUMERIC,
        venpCO2 NUMERIC,
        venpO2 NUMERIC,
        venTEMP NUMERIC,
        SO2 NUMERIC,
        HCT NUMERIC,
        HB NUMERIC
)""")
conn.commit()

# %%
c.execute(
        "INSERT INTO cdi (Time, artpH, artpCO2, artpO2, artTEMP, HCO3, BE, cSO2, K, VO2, Q, BSA, venpH, venpCO2, venpO2, venTEMP, SO2, HCT, HGB) VALUES(:Time, :artpH, :artCO2, :artO2, :artTEMP, :HCO3, :BE, :cSO2, :K, :VO2, :Q, :BSA, :venpH, :venCO2, :venO2, :venTEMP, :SO2, :HCT, :HGB)",
        {'Time': 154113,
         'artpH': 7.44,
         'artpCO2': 40,
         'artpO2': 100,
         'artTEMP': 37.1,
         'HCO3': 20,
         'BE': -4.5,
         'cSO2': 98,
         'K': 5.4,
         'VO2': 0,
         'Q': 0,
         'BSA': 0,
         'venpH': 7.2,
         'venpCO2': 50,
         'venpO2': 50,
         'venTEMP': 36.9,
         'SO2': 85,
         'HCT': 23,
         'HGB': 7.8
         })
conn.commit()
# Out:
# ----------------------------------------------------------
# OperationalError         Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 c.execute(
#       2         "INSERT INTO cdi (Time, artpH, artpCO2, artpO2, artTEMP, HCO3, BE, cSO2, K, VO2, Q, BSA, venpH, venpCO2, venpO2, venTEMP, SO2, HCT, HGB) VALUES(:Time, :artpH, :artCO2, :artO2, :artTEMP, :HCO3, :BE, :cSO2, :K, :VO2, :Q, :BSA, :venpH, :venCO2, :venO2, :venTEMP, :SO2, :HCT, :HGB)",
#       3         {'Time': 154113,
#       4          'artpH': 7.44,
#       5          'artpCO2': 40,
#       6          'artpO2': 100,
#       7          'artTEMP': 37.1,
#       8          'HCO3': 20,
#       9          'BE': -4.5,
#      10          'cSO2': 98,
#      11          'K': 5.4,
#      12          'VO2': 0,
#      13          'Q': 0,
#      14          'BSA': 0,
#      15          'venpH': 7.2,
#      16          'venpCO2': 50,
#      17          'venpO2': 50,
#      18          'venTEMP': 36.9,
# ...

# %%
c.execute("DROP TABLE cdi");
# Out:
# ----------------------------------------------------------
# OperationalError         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[56], line 1
# ----> 1 c.execute("DROP TABLE cdi");
#
# OperationalError: database is locked
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt        Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\interactiveshell.py:3693, in InteractiveShell.run_code(self, code_obj, result, async_)
#    3691 except:
#    3692     if result is not None:
# -> 3693         result.error_in_exec = sys.exc_info()[1]
#    3694     self.showtraceback(running_compiled_code=True)
#    3695 else:
#
# KeyboardInterrupt:

# %%
c.execute("""CREATE TABLE IF NOT EXISTS cdi(
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        Time NUMERIC NOT NULL,
        artpH NUMERIC)""")
conn.commit()

# %%
c.execute(
        "INSERT INTO cdi (Time, artpH) VALUES (:Time, :artpH)", {'Time': 154113,'artpH': 7.44})
conn.commit
# Out:
# <function Connection.commit()>

# %%
c.execute("SELECT * FROM cdi");

# %%
print(c.fetchall())
# Out:
# [(1, 154113, 7.44)]
